# %%
import json
from pprint import pprint

# %%
with open('metrics.json', 'r') as f:
    r = json.load(f)

# %%
metrics = r['metrics']

# %%
metrics[0]
# Out:
# {'model_file': '/data/imgai/clean-dirty-garbage-containers/models/detection_model-ex-001--loss-0031.630.h5',
#  'using_iou': 0.5,
#  'using_object_threshold': 0.3,
#  'using_non_maximum_suppression': 0.5,
#  'average_precision': {'container': 0.5166068384350663},
#  'evaluation_samples': 1195,
#  'map': 0.5166068384350663}

# %%
metrics.sort(key=lambda x:x['model_file'])

# %%
pprint(metrics)
# Out:
# [{'average_precision': {'container': 0.5166068384350663},
#   'evaluation_samples': 1195,
#   'map': 0.5166068384350663,
#   'model_file': '/data/imgai/clean-dirty-garbage-containers/models/detection_model-ex-001--loss-0031.630.h5',
#   'using_iou': 0.5,
#   'using_non_maximum_suppression': 0.5,
#   'using_object_threshold': 0.3},
#  {'average_precision': {'container': 0.6259594386151961},
#   'evaluation_samples': 1195,
#   'map': 0.6259594386151961,
#   'model_file': '/data/imgai/clean-dirty-garbage-containers/models/detection_model-ex-002--loss-0022.056.h5',
#   'using_iou': 0.5,
#   'using_non_maximum_suppression': 0.5,
#   'using_object_threshold': 0.3},
#  {'average_precision': {'container': 0.6662541641298019},
#   'evaluation_samples': 1195,
#   'map': 0.6662541641298019,
#   'model_file': '/data/imgai/clean-dirty-garbage-containers/models/detection_model-ex-003--loss-0020.172.h5',
#   'using_iou': 0.5,
#   'using_non_maximum_suppression': 0.5,
# ...
